# %% [markdown]
# Part A: Implementing Convolutional Neural Network from Scratch

# %%
# !pip install tensorflow numpy streamlit
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting streamlit
#   Downloading streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.2.1)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.40.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading streamlit-1.45.1-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 44.2 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 49.7 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.45.1 watchdog-6.0.0

# %%
import tensorflow as tf
import numpy as np
import streamlit as st

print("TensorFlow version:", tf.__version__)
print("NumPy version:", np.__version__)
print("Streamlit version:", st.__version__)
# Out:
# TensorFlow version: 2.18.0
# NumPy version: 2.0.2
# Streamlit version: 1.45.1

# %%
# Importing Libraries
import os

from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Unzipping directly to Colab temporary storage (faster access)

# !unzip "/content/drive/MyDrive/Flower_Dataset1.zip" -d "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/00a7d512d6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/00f36a3c40.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/013628cccc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/01998d6fb5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/01a0ec319c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/01b4bb0289.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/025ef3ea44.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/02a7a2df46.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/02be2ca388.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/035cce082f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/039eba79d4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/04067b91d6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/04acfd5449.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/05777790e2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/05b341b09f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/05bacec652.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/061b383a6f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/066ada304b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/06a98cb9ca.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/06d90ec8dd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/071a1b2099.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/071ce35ff5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/07979dd880.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/079f3fa65a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/07b4069f9d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/08186a8cb8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/08733b7c68.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/087568f59f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/08ddd943fd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0934dd1dde.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/097c54d702.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0a3700189a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0b1b4fb598.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0c1ec48a64.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0c7b09b5d3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0c98308a08.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0cd15008ae.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0d0d9402ae.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0d65659910.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0da73f3c61.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0da98adfa1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0dbd885982.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0dd416ef58.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0dd636f187.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0df4b52aca.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0f08548ec8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0f2d4ef658.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0f402885f5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0f684636c4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0f6847636c4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/0fac5ec114.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1043c87d6a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1090ed9db5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/109aec2c56.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/10c20f0c33.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/10f7f77092.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/110075880f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1211db22f4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/12935fbcac.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/12973b0880.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/12d9e24cb9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/12e1379ffe.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/12e3fd8c3c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/131cd3ed73.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1347ba3107.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1412e4fff9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/14993f6ce4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/14a9fd92a7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1557e7bc6e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1571f4ae2d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/15795a4e91.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/15c8c26d27.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/15ffd6deaa.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1664ae79c6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/168c8bc2ee.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/16af57945f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/16d58d78b8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/173bdc92e2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1766dab188.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/177cf77bf7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1783ef85a1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/17a173e95d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/17c939db14.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/17da77fc26.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/184522aa50.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/184f73e80f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/18ce641680.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1919378782.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1925720ad2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/19b61d6fe0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1a033ee4a4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1a22da532a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1a35c09e8d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1ab6cf04fd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1b621680ec.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1b6b32faa4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1b7aff1590.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1bc0be1e8d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1c41120cf0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1ca1f66c48.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1caebba6cc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1cc501a2ea.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1cc938684b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1d8ae6f9d9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1decdf8eaa.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1e17597391.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1e747772c8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1eb93c8043.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1ed8e39a36.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1eee44667a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1f44108a56.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/1fedf7f09e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2059e8ade4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/20b61d9ec7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/20d4ff8a44.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/20d5e68c37.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/20db89edc0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/210ce30970.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/21212d6991.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/216b1f1235.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/21cbd18b2e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/224e9dc2fc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/228928c23d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/234c5519c5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/236e8c9c4d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/23b1cf4e47.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/248320efa7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/24f8efe172.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/25824d354d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/25be0fa8cc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2703a19d40.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/270779aaab.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2794fc1ff3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2824ba3315.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2825468af2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2827b3b234.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/28d7761c8d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/28eded08a1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/294f62d399.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/295bd95399.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/29a523175b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/29b320cb91.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/29d48885e7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2a2616437e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2a2a49ed9a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2a9b2008c6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2aa471d38f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2b0944d8f5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2b0a191210.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2b10438c7c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2ba69e8ea3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2c222d2a93.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2c68eb48b9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2c910f4007.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2cb6caa508.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2cc7d01b01.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2ccb23f3dd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2cd987941f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2d1ec5a0a6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2d985b4228.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2d9fbc98d1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2dcf75cc39.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2df691031c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2e16985dbd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2e23773349.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2e27705156.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/2f64eabf41.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3009a59422.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/301b28fabe.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/30356bc116.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3070028ace.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/30837c8454.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/30918b00e2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3093726c21.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/30c8a0495c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/30ef1f3151.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3180ab874d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3193d4e81e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/31e855cedd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/31eda67b8c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3205f4a45d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3239f52a8e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/325d1de8f7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/32a2da4f74.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/32b483906d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/32d376752c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/334c1f79fd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/336f11c70d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3373be4bcd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/33ae76d160.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/33b4d9f96f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/33bec02458.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/342e7142b1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/34529000cc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/34682bf1b7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/347433abca.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/35282168f3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3554e3e4f2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/358c237692.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/359ebd8e74.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/36202ad0aa.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/367f19f54f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/36c52675a8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/36cd969b55.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/374709d0e1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/37480991f7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/375b7e9c9b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/37ddde8546.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/37f57ac51e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3816803c11.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/382227711b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3848db19a5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/384f5a6054.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/397d2808ed.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/39bdedf204.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3a07c14473.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3a1fe3fb75.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3aa55837fd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3b02f00482.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3b1dae4a0d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3bfce7929b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3c16da3049.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3c3627e073.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3c792177e9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3cbc4d94f3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3d2c5bc5fb.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3d68be84ab.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3dae2a0715.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3db967ce4f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3dd82ec064.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3de4b0e19c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3e661ed25f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3ea06dd08e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3f35330c00.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3f45ba2590.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/3fd23f812f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4033b67909.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/405620274c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/406b4ed7d1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/407b16afc9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/40bd97213d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4166ac8aea.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/41996dd2ba.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/422a534afa.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/423527ea88.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/423d55cb7b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4241b39d49.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4289d9d254.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/42ad6f53bf.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/434ae90611.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/434b2ccea1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4392605a61.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/43a8d01638.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/43f5be4e8d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/449624d611.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/44fe9f3983.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/452b1be269.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/452fa7109a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/45640012d3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/469764c8e2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4739f59723.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/47869a8d47.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/47895917ba.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4795abe765.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/47c7e6e433.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/47d9ffb79b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4829351a69.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/484ea5b126.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/48b57b7bec.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4904264328.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/490dedccad.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/49536e29ed.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/49ea7130c2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4a57067c87.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4aaddae03b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4ab67c7fb7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4ac39a26ee.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4ade8bcbbe.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4b04897044.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4b8e33ef6e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4b937b1208.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4bd5ee0dd7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4c26b2bee1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4c4fa93e1d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4c6e0e1f04.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4c8c0ba072.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4cb2c5dea5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4d0a669ea1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4d2efa5423.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4d9072a54e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4d941abea8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4dd4cf4977.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4df5e794a4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4dfcf5c5b5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e05f37a58.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e2eb326e2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e3112cd97.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e3dd0e535.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e40681b65.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e57ab95dc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e8c030a48.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e9c69f4b3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4e9db8cd2d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4f531a2e64.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/4fc228dab4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/50434d1637.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/50923fb339.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/50e5da27a8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5117f2a7de.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/512883ba70.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/51473e2dcd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5153d1ad6e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5172ad48cf.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/51a44de867.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/52178f21ae.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/52236b1a56.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/52b76bc761.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/52d2e67d73.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/52e21895e6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/52ef67fc65.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5327d261b6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/532a8ef4d5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/53815c5e4d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/539cde3977.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/53a892dd58.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/541caddb11.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5455e08529.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5490580148.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5491cb74d3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/54b5f79ea2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/55507d0cb5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/55752e9705.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/55cc7bd6bb.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/562d47941a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/56efcbdf64.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/571aa37cf1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/57229fa626.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/572efd9348.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/573b7dddd2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/57bf174076.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/58239ddadd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5857e34aba.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/586085c837.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/58824f7290.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/590f5d7b01.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/59156527f5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5924fc5e6e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/593b473dbc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/59501a47d7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5958836eb1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/598e9f0c2d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5a0e606efc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5a140d4867.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5a2c1de8aa.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5a3a477ac1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5a475651c5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5b34f9c2d7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5b51e8145d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5b70da4276.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5b91dfcbdf.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5c63c0b883.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5cb4ad630d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5d3ed7cc48.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5d5c28001c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5dbb611e66.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5e02a3701b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5e40d4d6d8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5f1af10817.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5f35baa700.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5f3d578353.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5f7c2af630.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/5fe46517e0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6072ba60b9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/60a779d75a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/60a9226675.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/60b7bd577c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/60ca6914d6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/61a95aca7b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/61ce30a8fc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6222ca86e2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/622ff376b1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6234950cf2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/62b63643fc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/62dbc22905.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/62dbd8d39a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/632f8ca14c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/63cc03ede0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/63ef2b310f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6412799dc6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6445794dd5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/651b645c81.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/654799146e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/65c455cb32.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/65ca49a1f6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/65d9916c17.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/65da161979.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/660e940b8c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/66947d2ed4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6696318393.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/66e8e3efe5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6713fd7f88.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/67ba5a13f7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/67d5e30f73.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/680ae3efc5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/68248d934f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/683152d11a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6867863801.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/68ee60ed96.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/692c9b201d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/695d17ceb5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/69ac84afb7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/69af070714.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/69c25901e0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6a61f8f8d7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6a7043d0e2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6a9ae31d4a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6ad00b0fd8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6af00c9920.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6b4f5756a6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6b6e2cb329.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6ba2f81b96.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6c1a9e5e43.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6c872153c9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6c9542afad.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6caae13aa7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6d1f4c6e16.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6d219d61d7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6d349e828a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6d5d08a44a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6d708c4c86.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6d77f956d3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6d9680d258.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6e8059d864.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6eb1825b00.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6f244998c5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6f491a5125.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6fc7ad8c16.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/6ffc9b2185.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/709948c994.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/719cedd667.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/71f0ed1d87.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7210ea9bbc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/725e58cecd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7279c9b30d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/73516e9881.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7351ce4e74.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/73c4147071.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/74308a6033.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/749412e02d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/74fd14bf0d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7504965fdb.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/750f82f03d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/75c239bad5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/761830f617.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/761c1bc24e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/763a1228e0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/767853a0f5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/769a385b3e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/76a98d9f9f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/77d138da84.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/77d4dd1ead.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7820e1135c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/782e41c92e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/78ad87f86a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/78d5a5618b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/78e4e227a3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7905bec55f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/790c74dec8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/798d286f28.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/79df54b811.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/79e7dcd748.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/79e7fb2497.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/79f9d154e3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7a06a27291.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7ac5bb68a2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7acd4b5e09.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7b40c4cd29.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7b6ced5cd3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7b918526f1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7bb31a95bd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7bd90ccd2f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7c123ce5b9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7c46ad198c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7cfec87280.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7d8e59239e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7dbdc4ad48.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7dc25a962d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7dd0a0bc05.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7de8d00f08.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7de8fcebe9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7e080acb06.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7e8ff84fea.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7f1de4c013.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7f8b17c1ea.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/7ffd7bc35d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/803230a3a8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/803eb645a7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8058a2974c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/80adf879e9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/80bbf7b08d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/80f2e145d5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/811045ef8f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8167b803ee.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/817f85db7f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8201b963b9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/82365a32d3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/828df83e2d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/82922fc82b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/829adadb3b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/82b724350e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/82bc28831e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/82cb61e4a1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/82e9774503.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/830a50f038.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8320c9d5be.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/834ddd0190.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/83657b8b10.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/83ba8e1668.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/84042e2885.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/844d7f05b0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/846961cba4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/84d49f6fe7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/84e3751150.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/84f72d9c24.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/84fc3819e7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8548cb621d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/854de73eca.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/85520c848c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/856306bff3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/86543db2e9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/86c3f206b3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/86d16fad82.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/87147c6c1f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/871fa68fdd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8720a46d82.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8732172969.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/87576e716c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/878805cdab.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/883432a6cf.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/88421e6af9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/884afa0a46.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/88510c29d3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/88650948fc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/889124b13b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/88fb780809.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8972d03e70.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/89f8e61cb0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8a6c8d4fc5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8a8c27d93c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8aa7c0fb8f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8ae013cf70.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8af266261d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8b2fad88f7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8b5223d1b8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8c4e691485.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8c95d3eab5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8d0504487a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8d65dfb2ac.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8dcd8e018b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8ddc934af1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8de9279b30.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8e24823cf9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8e4cb4b693.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8e690a61ca.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8ee1e314ec.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8ee27d05e7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8ef83e2462.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8efaf49b69.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8f61a0ef5f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8f72f50f8c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8f9b2aa6fd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/8fe76f3a5b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9042aabf7a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/904ab3c80d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/909abffb3e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/910b1e8c3b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9112a2ab9b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9181db1ddc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9217213773.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9228a9d2c4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/923f605132.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9272958192.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9318c50eb0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/93519f856f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9392e439de.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/94f8d3f7d9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/94fa22a98c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9509bc69dc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/950dfee63b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/951130d9d9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/956db102f2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/961aa3256d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/966d4a5772.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/96995c7183.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/96f16c6a27.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/973be5f5c8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9776a9ed97.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/982951d839.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/98490e42fb.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/989c94a006.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/98b24541b7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/98bbde67e0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/991909cfef.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9923eb817b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9971111b04.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/99841f8a87.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/999dcd68ee.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/99af4087fc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/99b063ae10.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/99b63ccc55.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/99f6aaedea.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9a469f273f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9a82c27396.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9b355ec7a6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9c02c31622.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9c9e2a7f7e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9cd4a405eb.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9ce11bd3c1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9d41cd0bbc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9e07d58bdc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9e8124b819.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9ed34bf899.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9f2954b3a9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9f4426527a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9f6df85e89.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9f8c97475e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9fda8e3303.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/9fdc8d8868.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a017dcfc8e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a0372744a2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a0957ec347.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a0e207ff22.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a0e7fefca0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a109870520.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a1221c07dd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a1bca53f96.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a1c2b83bf4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a255e8a11a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Lilly/a2ee8a6c3b.jpg
# ...
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/c9e6918606.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/c9ff0a8e70.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ca1ac4e849.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cabdf6e8a5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/caed8c554b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cb0f2b9621.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cb69f30397.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cb73c9c5ad.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cb829f72d7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cb8a78e2dd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cbab8f0c11.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cbf57bbe16.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cc60e5448b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cc82bbc3e3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ccc0dbe558.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cdab6954c2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cdb5ccd80f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cdeb46fb15.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ce12b5e0e1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ce59a726ec.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ced5e76b71.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cf4718ac1c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cf66f7d5a8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cfb4a1c31d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/cfdd60ad76.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d02b6ffe46.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d04ce3945c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d058755665.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d078306f3b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d1329f567a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d144f150b5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d14e75812f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d1661121ff.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d1c2373698.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d1e5f77547.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d1ed6fff9e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d24fa842b7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d31d9dd62e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d323ae3ede.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d33f75d989.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d3a1b58707.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d3ab96f944.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d3c295090d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d3c66d5740.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d457c09053.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d4eeef528e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d578e6557e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d5889354f9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d5b268d92d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d5f5e526f9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d61608aa3a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d6758b0054.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d6a50d65ed.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d6d32207de.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d6e25ebc11.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d75f12961c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d798773c09.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d7b80257d9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d7f3079842.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d8096b2a64.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d864137f0c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d86cd0558b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d87d50d2c8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d896d803a1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d8a45a54b3.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d8b6fe562e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d8c34ef4b8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d9087f286b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d9ebe6c87d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/d9ef6b2e06.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/da0c9e3ecc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/da3b1748fe.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/da450693cf.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/da9a9cbe11.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dab17f47d7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dab259191a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dab40fe054.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/db44745bd5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dbb42eedac.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dbf7e99529.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dcbd1aaa69.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dd3d9a8324.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dd484c0288.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ddae397fa5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ddb51457ac.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dde043aedc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/de996d48ea.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/deae9e6ea0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/df45cb04a2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/dfdc506610.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e021bf6132.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e08a5bb33a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e09ae45d21.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e0c0bdf8ec.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e1b30b02cb.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e1b83de1c5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e2beadb878.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e2c3cc40ca.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e2e14f8f10.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e2fca2921b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e308628c5c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e31de29088.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e323a47d05.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e4377e923e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e46eb3a1a0.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e4720c3c74.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e4750b169c.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e4949001ea.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e4c487eb47.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e4cab6274f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e4d38d51e7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e5174fed77.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e53093ee59.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e53639b8a5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e543c41dd5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e5731eb449.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e599f9cc56.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e6269ddf63.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e6ddc6aa4b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e6e40cb833.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e6ea9e6d43.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e7a3fd9731.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e8136e73ee.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e8844416a1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e8d3b89c15.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e9225f8ac4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e93e3dd4aa.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e9591a3935.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e9644acc02.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e9bd2e7d21.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e9c0a30b47.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e9c8b37718.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/e9fd559834.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/eaaebbaf8e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/eaf91d1834.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/eaf9c2e1f1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/eb2e456c5f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ebb06a3e80.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ec293cdc83.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ec35a80185.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ec9ed77939.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ecc10d2bbb.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ecf9a53154.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ecfb74205a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ed0a34c865.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ed25362cde.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ed99da9224.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/eda2be3cfa.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/edb85a0a0d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ee29538c0e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/eeef054cde.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ef2f29e026.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ef54e5c968.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/efb43694b2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f074d7631a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f080401ac6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f104a78666.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f131697db6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f15612da9a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f1a715c883.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f1d7825a09.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f21fe889e1.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f2b087be5d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f34cefb0fe.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f363b5a2a9.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f3d5e25438.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f3e416125b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f4837be653.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f4e4ed64a6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f5422364db.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f62084bf47.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f64101086b.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f6422b2d77.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f64c8d3c4a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f66e621763.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f68552009f.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f6eaf7a021.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f73b53d954.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f77d6003f8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f80239b5ed.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f80ab21e05.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f823c8be17.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f8244b5cc8.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f91cc2ae21.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f945a94bdb.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f98b03ddf5.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/f9a81ccdfd.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fa30f9b4b6.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fa623bb2b7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fa76614f11.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/faa5295976.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/faa7d1ea18.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/facc0dd94a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fb8e4de2b7.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fbb9622c0a.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fbe91016d4.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fc97dd24e2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fd4936f798.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fda1d5d805.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fdb4c44dcf.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fdd0fffd19.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fdf01cea88.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fdf7635ab2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fe3e4cd6f2.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fe531595be.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fe5b51ef50.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fece276804.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/fee1d18e1d.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ff45bb890e.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ff86812721.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ff86812726.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ffcc5248bc.jpg
#   inflating: /content/Flower_Dataset1/flower_images/Tulip/ffcc5248bf.jpg

# %% [markdown]
# 3.1.1 Data Understanding, Analysis, Visualization and Cleaning

# %%
# Check the exact path where files landed
# !ls "/content/Flower_Dataset1/flower_images"
# Out:
# Lilly  Lotus  Orchid  Sunflower  Tulip

# %%
# Path to flower images
path = "/content/Flower_Dataset1/flower_images"

# Initialize total counter
total = 0

# Count images in each flower folder
for flower in os.listdir(path):
    flower_path = os.path.join(path, flower)
    if os.path.isdir(flower_path):
        count = len(os.listdir(flower_path))
        total += count
        print(f"{flower}: {count} images")

# Print total count
print(f"\nTotal images: {total}")
# Out:
# Tulip: 1000 images
# Sunflower: 1000 images
# Orchid: 1000 images
# Lotus: 1000 images
# Lilly: 1000 images
#
# Total images: 5000

# %%
# Load Images into Arrays as Dataset
# My parameters
base_dir = '/content/Flower_Dataset1/flower_images/'  # My Dataset Path
img_size = 180
batch = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'training',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))

val_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'validation',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))
# Out:
# Found 4999 files belonging to 5 classes.
# Using 4000 files for training.
# Found 4999 files belonging to 5 classes.
# Using 999 files for validation.

# %%
# Checking for Problematic files
import os
from pathlib import Path

image_exts = {'.jpg', '.jpeg', '.png', '.bmp', '.gif'}

base_dir = Path("/content/Flower_Dataset1/flower_images")
for root, _, files in os.walk(base_dir):
    for file in files:
        if Path(file).suffix.lower() not in image_exts:
            print("Non-image file:", os.path.join(root, file))
# Out:
# Non-image file: /content/Flower_Dataset1/flower_images/Lilly/efa0739yt4jpg

# %%
import os
from PIL import Image

# Path to my flower dataset
base_path = "/content/Flower_Dataset1/flower_images"

# List of my flower folders
flower_folders = ['Lotus', 'Sunflower', 'Orchid', 'Lilly', 'Tulip']

# Initialize counter
corrupted_files_found = False

print("Checking for corrupted images...\n")

for folder in flower_folders:
    folder_path = os.path.join(base_path, folder)
    if not os.path.exists(folder_path):
        print(f"Folder not found: {folder}")
        continue

    print(f"Checking {folder}...")
    for filename in os.listdir(folder_path):
        filepath = os.path.join(folder_path, filename)

        try:
            # Try to open and verify the image
            with Image.open(filepath) as img:
                img.verify()  # Basic verification
        except Exception as e:
            print(f"  Corrupted: {filename}")
            corrupted_files_found = True

if not corrupted_files_found:
    print("\n No corrupted files found in any folder!")

print("\nCheck Complete.")
# Out:
# Checking for corrupted images...
#
# Checking Lotus...
# Checking Sunflower...
# Checking Orchid...
# Checking Lilly...
# Checking Tulip...
#
#  No corrupted files found in any folder!
#
# Check Complete.

# %%
flower_names = train_ds.class_names
flower_names
# Out:
# ['Lilly', 'Lotus', 'Orchid', 'Sunflower', 'Tulip']

# %%
import matplotlib.pyplot as plt

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3,3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(flower_names[labels[i]])
        plt.axis('off')

# %%
# CACHI CONCEPT

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %%
# Data Augmentation
data_augmentation = Sequential([
    layers.RandomFlip("horizontal", input_shape = (img_size,img_size,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        images = data_augmentation(images)
        plt.subplot(3,3, i+1)
        plt.imshow(images[0].numpy().astype('uint8'))
        plt.axis('off')

# %% [markdown]
# 3.1.2 Design, Train, and Evaluate a Baseline Model
# 1. Model Architecture:

# %%
# Model Creation
model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    Conv2D(16, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(5)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 90, 90, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 45, 45, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 45, 45, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 30976)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,965,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,989,285 (15.22 MB)
#  Trainable params: 3,989,285 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_ds, epochs=15, validation_data=val_ds)
# Out:
# Epoch 1/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - accuracy: 0.3736 - loss: 1.5577 - val_accuracy: 0.5676 - val_loss: 1.1009
# Epoch 2/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5633 - loss: 1.0665 - val_accuracy: 0.5796 - val_loss: 1.0701
# Epoch 3/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.6036 - loss: 1.0019 - val_accuracy: 0.6386 - val_loss: 0.9366
# Epoch 4/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.6384 - loss: 0.9148 - val_accuracy: 0.6416 - val_loss: 0.8857
# Epoch 5/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.6532 - loss: 0.8876 - val_accuracy: 0.6727 - val_loss: 0.8434
# Epoch 6/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6897 - loss: 0.8162 - val_accuracy: 0.6627 - val_loss: 0.8866
# Epoch 7/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7087 - loss: 0.7618 - val_accuracy: 0.6857 - val_loss: 0.7930
# Epoch 8/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7179 - loss: 0.7338 - val_accuracy: 0.6156 - val_loss: 0.9575
# Epoch 9/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7141 - loss: 0.7258 - val_accuracy: 0.7247 - val_loss: 0.7272
# Epoch 10/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7548 - loss: 0.6426 - val_accuracy: 0.7107 - val_loss: 0.7612
# Epoch 11/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.7661 - loss: 0.6060 - val_accuracy: 0.7387 - val_loss: 0.6897
# Epoch 12/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7722 - loss: 0.5974 - val_accuracy: 0.7247 - val_loss: 0.7414
# Epoch 13/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7910 - loss: 0.5530 - val_accuracy: 0.7618 - val_loss: 0.6714
# Epoch 14/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8035 - loss: 0.5096 - val_accuracy: 0.7698 - val_loss: 0.6272
# Epoch 15/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8067 - loss: 0.5170 - val_accuracy: 0.7668 - val_loss: 0.6352

# %% [markdown]
# 2. Model Test

# %%
from google.colab import drive
import os
import zipfile

# Mount Google Drive
drive.mount('/content/drive')

# Path to my zip in Drive
zip_path = '/content/drive/MyDrive/SampleFlower_Dataset.zip'

# Unzip to Colab temporary storage
extract_path = '/content/test_flowers'
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Files extracted to: {extract_path}")
print(os.listdir(extract_path))  # Verify files
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files extracted to: /content/test_flowers
# ['SampleFlower_Dataset']

# %%
# My original function
# FOR SINGLE IMAGE
def classify_images(image_path):
    input_image = tf.keras.utils.load_img(image_path, target_size=(180,180))
    input_image_array = tf.keras.utils.img_to_array(input_image)
    input_image_exp_dim = tf.expand_dims(input_image_array,0)

    predictions = model.predict(input_image_exp_dim)
    result = tf.nn.softmax(predictions[0])
    outcome = 'The Image belongs to ' + flower_names[np.argmax(result)] + ' with a score of '+ str(np.max(result)*100)
    return outcome

# Usage (add this after your function):
image_path = "/content/test_flowers/SampleFlower_Dataset/Sunflower1.jpg"  # My IMAGE PATH
print(classify_images(image_path))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# The Image belongs to Sunflower with a score of 99.99996

# %%
# SINGLE IMAGE CODE
def classify_images(image_path):
    input_image = tf.keras.utils.load_img(image_path, target_size=(180,180))
    input_image_array = tf.keras.utils.img_to_array(input_image)
    input_image_exp_dim = tf.expand_dims(input_image_array,0)

    predictions = model.predict(input_image_exp_dim)
    result = tf.nn.softmax(predictions[0])
    outcome = 'The Image belongs to ' + flower_names[np.argmax(result)] + ' with a score of '+ str(np.max(result)*100)
    return outcome

# %%
classify_images('/content/test_flowers/SampleFlower_Dataset/Tulip1.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 'The Image belongs to Tulip with a score of 99.81399'

# %%
# Classify all images in the test folder
#FOR MULTIPLE IMAGES
test_images_path = os.path.join(extract_path, 'SampleFlower_Dataset')  # Path

for img_file in os.listdir(test_images_path):
    if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
        full_path = os.path.join(test_images_path, img_file)
        try:
            result = classify_images(full_path)
            print(f"Image: {img_file}")
            print(result)
            print("-" * 50)
        except Exception as e:
            print(f"Error processing {img_file}: {str(e)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: Lily2.jpg
# The Image belongs to Lilly with a score of 90.86517
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: Orchid1.jpg
# The Image belongs to Orchid with a score of 99.40246
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Image: Sunflower1.jpg
# The Image belongs to Sunflower with a score of 99.99996
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Image: Lily1.jpeg
# The Image belongs to Lilly with a score of 86.10788
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Image: Sunflower2.jpg
# The Image belongs to Sunflower with a score of 99.99998
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Image: Lotus2.jpg
# The Image belongs to Lotus with a score of 97.72818
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Image: Lotus1.jpg
# The Image belongs to Lotus with a score of 99.86273
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Image: Tulip2.jpg
# The Image belongs to Tulip with a score of 99.60698
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Image: Tulip1.jpg
# The Image belongs to Tulip with a score of 99.81399
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Image: Orchid2.jpg
# The Image belongs to Orchid with a score of 76.6189
# --------------------------------------------------

# %% [markdown]
# Plot Training vs Validation Loss

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Evaluate Metrics (Precision, Recall, F1)

# %%
from sklearn.metrics import classification_report
import numpy as np

# Get predictions
y_pred = []
y_true = []
for images, labels in val_ds:
    y_pred.extend(np.argmax(model.predict(images), axis=-1))
    y_true.extend(labels.numpy())

print(classification_report(y_true, y_pred, target_names=flower_names))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#               precision    recall  f1-score   support
#
#        Lilly       0.63      0.65      0.64       178
#        Lotus       0.79      0.78      0.79       197
#       Orchid       0.63      0.82      0.71       200
#    Sunflower       0.94      0.96      0.95       209
#        Tulip       0.89      0.60      0.72       215
#
#     accuracy                           0.77       999
#    macro avg       0.78      0.76      0.76       999
# weighted avg       0.78      0.77      0.77       999

# %% [markdown]
# Inference on Sample Images

# %%
def predict_and_plot(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(img_size, img_size))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Add batch dimension

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    predicted_class = flower_names[np.argmax(score)]

    plt.figure()
    plt.imshow(img)
    plt.title(f"Predicted: {predicted_class}\nConfidence: {100 * np.max(score):.2f}%")
    plt.axis('off')
    plt.show()

# Test on a sample
predict_and_plot('/content/test_flowers/SampleFlower_Dataset/Tulip1.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %% [markdown]
# Deeper Model with Regularization
#
# Deeper Model Architecture

# %%
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2  # For L2 regularization

deeper_model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(256, 3, padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Flatten(),
    layers.Dense(256, activation='relu', kernel_regularizer=l2(0.01)),  # L2 regularization
    layers.Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    layers.Dense(5)
])

deeper_model.compile(optimizer='adam',
                    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])
deeper_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 180, 180, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 180, 180, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 90, 90, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 90, 90, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 90, 90, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 45, 45, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 45, 45, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 45, 45, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 22, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 22, 22, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 22, 22, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 11, 11, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 11, 11, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 30976)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     7,930,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,353,989 (31.87 MB)
#  Trainable params: 8,353,029 (31.86 MB)
#  Non-trainable params: 960 (3.75 KB)

# %% [markdown]
# Train & Compare

# %%
deeper_history = deeper_model.fit(train_ds, epochs=15, validation_data=val_ds)

# Compare training time
import time
start_time = time.time()
deeper_model.fit(train_ds, epochs=15, validation_data=val_ds)
training_time = time.time() - start_time
print(f"Deeper Model Training Time: {training_time:.2f} sec")
# Out:
# Epoch 1/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - accuracy: 0.3989 - loss: 12.3190 - val_accuracy: 0.2482 - val_loss: 8.6570
# Epoch 2/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.4727 - loss: 7.1146 - val_accuracy: 0.3363 - val_loss: 5.6777
# Epoch 3/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.5464 - loss: 4.5146 - val_accuracy: 0.4965 - val_loss: 3.6283
# Epoch 4/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.5977 - loss: 3.2896 - val_accuracy: 0.5115 - val_loss: 3.1630
# Epoch 5/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.6181 - loss: 2.7972 - val_accuracy: 0.6366 - val_loss: 2.3685
# Epoch 6/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - accuracy: 0.6350 - loss: 2.3530 - val_accuracy: 0.6446 - val_loss: 2.2927
# Epoch 7/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - accuracy: 0.6590 - loss: 2.1648 - val_accuracy: 0.6116 - val_loss: 2.1517
# Epoch 8/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 105ms/step - accuracy: 0.6591 - loss: 1.9961 - val_accuracy: 0.3253 - val_loss: 3.9212
# Epoch 9/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.7010 - loss: 1.8524 - val_accuracy: 0.7017 - val_loss: 1.7820
# Epoch 10/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - accuracy: 0.7017 - loss: 1.7698 - val_accuracy: 0.6847 - val_loss: 1.7402
# Epoch 11/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.7271 - loss: 1.6011 - val_accuracy: 0.7247 - val_loss: 1.6402
# Epoch 12/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.7310 - loss: 1.6091 - val_accuracy: 0.6687 - val_loss: 1.7219
# Epoch 13/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.7254 - loss: 1.5194 - val_accuracy: 0.7287 - val_loss: 1.5306
# Epoch 14/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - accuracy: 0.7634 - loss: 1.3909 - val_accuracy: 0.7307 - val_loss: 1.5462
# Epoch 15/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.7633 - loss: 1.4309 - val_accuracy: 0.7307 - val_loss: 1.5031
# Epoch 1/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 105ms/step - accuracy: 0.7758 - loss: 1.3758 - val_accuracy: 0.7407 - val_loss: 1.4901
# Epoch 2/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.7875 - loss: 1.3695 - val_accuracy: 0.6907 - val_loss: 1.5453
# Epoch 3/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.7963 - loss: 1.2905 - val_accuracy: 0.7417 - val_loss: 1.3789
# Epoch 4/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - accuracy: 0.7921 - loss: 1.2826 - val_accuracy: 0.7467 - val_loss: 1.4574
# Epoch 5/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.7956 - loss: 1.2769 - val_accuracy: 0.7387 - val_loss: 1.4411
# Epoch 6/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.8258 - loss: 1.2167 - val_accuracy: 0.7367 - val_loss: 1.4507
# Epoch 7/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.8284 - loss: 1.1849 - val_accuracy: 0.7457 - val_loss: 1.4809
# Epoch 8/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.8228 - loss: 1.1887 - val_accuracy: 0.7477 - val_loss: 1.4898
# Epoch 9/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8505 - loss: 1.0908 - val_accuracy: 0.7858 - val_loss: 1.3160
# Epoch 10/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.8403 - loss: 1.1142 - val_accuracy: 0.7808 - val_loss: 1.2809
# Epoch 11/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8648 - loss: 1.0255 - val_accuracy: 0.6907 - val_loss: 1.7992
# Epoch 12/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - accuracy: 0.8598 - loss: 1.0443 - val_accuracy: 0.8058 - val_loss: 1.3535
# Epoch 13/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.8672 - loss: 1.0987 - val_accuracy: 0.8028 - val_loss: 1.2288
# Epoch 14/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.8691 - loss: 0.9603 - val_accuracy: 0.6056 - val_loss: 2.1178
# Epoch 15/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - accuracy: 0.8921 - loss: 0.9331 - val_accuracy: 0.8178 - val_loss: 1.2131
# Deeper Model Training Time: 224.41 sec

# %% [markdown]
# Experimentation & Analysis

# %% [markdown]
# Complete Comparison Code (Metrics + Training Time)

# %%
import time
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# =====================
# 1. Evaluate Baseline Model
# =====================
print("\n=== Baseline Model Evaluation ===")
# Get predictions
y_true_baseline, y_pred_baseline = [], []
for images, labels in val_ds:
    y_pred_baseline.extend(np.argmax(model.predict(images), axis=-1))
    y_true_baseline.extend(labels.numpy())

# Metrics
print(classification_report(y_true_baseline, y_pred_baseline, target_names=flower_names))

# Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_true_baseline, y_pred_baseline),
            annot=True, fmt='d', cmap='Blues', xticklabels=flower_names, yticklabels=flower_names)
plt.title('Baseline Model Confusion Matrix')
plt.show()

# =====================
# 2. Evaluate Deeper Model
# =====================
print("\n=== Deeper Model Evaluation ===")
# Get predictions
y_true_deeper, y_pred_deeper = [], []
for images, labels in val_ds:
    y_pred_deeper.extend(np.argmax(deeper_model.predict(images), axis=-1))
    y_true_deeper.extend(labels.numpy())

# Metrics
print(classification_report(y_true_deeper, y_pred_deeper, target_names=flower_names))

# Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_true_deeper, y_pred_deeper),
            annot=True, fmt='d', cmap='Blues', xticklabels=flower_names, yticklabels=flower_names)
plt.title('Deeper Model Confusion Matrix')
plt.show()

# =====================
# 3. Training Time Comparison
# =====================
def measure_training_time(model, train_data, epochs=5):
    start_time = time.time()
    model.fit(train_data, epochs=epochs, verbose=0)
    return time.time() - start_time

# Measure time (run a few epochs for fair comparison)
baseline_time = measure_training_time(model, train_ds.take(100), epochs=5)
deeper_time = measure_training_time(deeper_model, train_ds.take(100), epochs=5)

print(f"\nTraining Time Comparison (5 epochs):")
print(f"- Baseline Model: {baseline_time:.2f} seconds")
print(f"- Deeper Model: {deeper_time:.2f} seconds")
print(f"- Time Increase: {(deeper_time - baseline_time)/baseline_time * 100:.1f}%")

# =====================
# 4. Accuracy/Loss Comparison
# =====================
plt.figure(figsize=(12, 5))

# Accuracy Comparison
plt.subplot(1, 2, 1)
plt.plot(history.history['val_accuracy'], label='Baseline Model')
plt.plot(deeper_history.history['val_accuracy'], label='Deeper Model')
plt.title('Validation Accuracy Comparison')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss Comparison
plt.subplot(1, 2, 2)
plt.plot(history.history['val_loss'], label='Baseline Model')
plt.plot(deeper_history.history['val_loss'], label='Deeper Model')
plt.title('Validation Loss Comparison')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# === Baseline Model Evaluation ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#               precision    recall  f1-score   support
#
#        Lilly       0.63      0.65      0.64       178
#        Lotus       0.79      0.78      0.79       197
#       Orchid       0.63      0.82      0.71       200
#    Sunflower       0.94      0.96      0.95       209
#        Tulip       0.89      0.60      0.72       215
#
#     accuracy                           0.77       999
#    macro avg       0.78      0.76      0.76       999
# weighted avg       0.78      0.77      0.77       999
# === Deeper Model Evaluation ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
#               precision    recall  f1-score   support
#
#        Lilly       0.69      0.74      0.71       178
#        Lotus       0.91      0.77      0.84       197
#       Orchid       0.82      0.76      0.78       200
#    Sunflower       0.81      1.00      0.89       209
#        Tulip       0.88      0.81      0.85       215
#
#     accuracy                           0.82       999
#    macro avg       0.82      0.81      0.81       999
# weighted avg       0.82      0.82      0.82       999
# Training Time Comparison (5 epochs):
# - Baseline Model: 15.09 seconds
# - Deeper Model: 48.64 seconds
# - Time Increase: 222.4%

# %% [markdown]
# (2) Optimizer Analysis (SGD vs Adam)

# %%
# Train with SGD
deeper_model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
sgd_history = deeper_model.fit(train_ds, epochs=15, validation_data=val_ds)

# Compare SGD vs Adam
plt.plot(sgd_history.history['val_accuracy'], label='SGD Val Accuracy')
plt.plot(deeper_history.history['val_accuracy'], label='Adam Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - accuracy: 0.5762 - loss: 1.9949 - val_accuracy: 0.2863 - val_loss: 3.0096
# Epoch 2/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.4677 - loss: 2.7199 - val_accuracy: 0.3894 - val_loss: 2.2962
# Epoch 3/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.3100 - loss: 2.3822 - val_accuracy: 0.2422 - val_loss: 2.5450
# Epoch 4/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.2528 - loss: 2.2072 - val_accuracy: 0.2713 - val_loss: 2.3760
# Epoch 5/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.2816 - loss: 2.1558 - val_accuracy: 0.2913 - val_loss: 2.1480
# Epoch 6/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.2927 - loss: 2.0804 - val_accuracy: 0.2953 - val_loss: 2.0416
# Epoch 7/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.3128 - loss: 2.0800 - val_accuracy: 0.2713 - val_loss: 2.0785
# Epoch 8/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.2811 - loss: 2.0432 - val_accuracy: 0.2863 - val_loss: 2.0630
# Epoch 9/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 96ms/step - accuracy: 0.2845 - loss: 2.0671 - val_accuracy: 0.2272 - val_loss: 2.4196
# Epoch 10/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.2312 - loss: 2.4094 - val_accuracy: 0.2312 - val_loss: 2.3801
# Epoch 11/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 96ms/step - accuracy: 0.2369 - loss: 2.3704 - val_accuracy: 0.2352 - val_loss: 2.3425
# Epoch 12/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.2161 - loss: 2.3333 - val_accuracy: 0.2392 - val_loss: 2.3067
# Epoch 13/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.2305 - loss: 2.2980 - val_accuracy: 0.2392 - val_loss: 2.2726
# Epoch 14/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.2272 - loss: 2.2641 - val_accuracy: 0.2382 - val_loss: 2.2401
# Epoch 15/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 96ms/step - accuracy: 0.2371 - loss: 2.2322 - val_accuracy: 0.2382 - val_loss: 2.2089

# %% [markdown]
# (3) Final Comparative Analysis

# %%
print("Baseline Model Val Accuracy:", max(history.history['val_accuracy']))
print("Deeper Model Val Accuracy:", max(deeper_history.history['val_accuracy']))
print("Deeper Model (SGD) Val Accuracy:", max(sgd_history.history['val_accuracy']))
# Out:
# Baseline Model Val Accuracy: 0.7697697877883911
# Deeper Model Val Accuracy: 0.7307307124137878
# Deeper Model (SGD) Val Accuracy: 0.38938939571380615

# %%
# Saving Model
model.save('Flower_Recognition_Model.h5')
# Downloading
from google.colab import files
try:
    files.download('Flower_Recognition_Model.h5')
    print("Model downloaded successfully!")
except Exception as e:
    print(f"Error downloading model: {e}")
    print("You can manually download from Colab's file browser (left sidebar)")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model downloaded successfully!

# %%
# 1. Save as .keras (Recommended modern format)
deeper_model.save('best_flower_model.keras')

# # 2. Save as HDF5 (.h5)
# deeper_model.save('best_flower_model.h5')

from google.colab import files
files.download('best_flower_model.keras')

# %% [markdown]
# Part B: Fine-Tuning a Pre-Trained Model (Transfer Learning)

# %% [markdown]
# 1. Load Pre-Trained Model (ResNet50)
#
# Loading and Adapting a Pre-Trained Model

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models

# Load ResNet50 (pre-trained on ImageNet)
base_model = ResNet50(
    weights='imagenet',  # Load pre-trained weights
    include_top=False,   # Exclude the final classification layer
    input_shape=(224, 224, 3)  # ResNet expects 224x224 images
)

# Freeze the base model (optional, for feature extraction)
base_model.trainable = False

print("ResNet50 Base Model Summary:")
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# ResNet50 Base Model Summary:
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer_3[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 112, 112,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 112, 112,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 114, 114,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 56, 56,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 56, 56,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 56, 56,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 56, 56,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 56, 56,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 56, 56,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 56, 56,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 56, 56,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 56, 56,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 56, 56,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 56, 56,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 56, 56,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 56, 56,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 56, 56,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 56, 56,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 56, 56,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 56, 56,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 56, 56,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 56, 56,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 56, 56,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 56, 56,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 28, 28,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 28, 28,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 28, 28,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 28, 28,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 28, 28,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 28, 28,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 28, 28,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 28, 28,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 28, 28,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 28, 28,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 28, 28,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 28, 28,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 28, 28,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 28, 28,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 28, 28,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 28, 28,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 28, 28,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 28, 28,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 28, 28,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 28, 28,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 28, 28,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 28, 28,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 28, 28,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 28, 28,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 28, 28,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 28, 28,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 14, 14,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 14, 14,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 14, 14,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 14, 14,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 14, 14,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 14, 14,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 14, 14,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 14, 14,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 14, 14,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 14, 14,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 14, 14,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 14, 14,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 14, 14,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 14, 14,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 14, 14,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 14, 14,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 14, 14,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 14, 14,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 14, 14,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 14, 14,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 14, 14,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 14, 14,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 14, 14,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 14, 14,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 14, 14,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 14, 14,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 7, 7, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 7, 7,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 7, 7,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 7, 7,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 7, 7,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 7, 7,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 7, 7,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 7, 7,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# Modify Model Architecture

# %%
# Add new classification layers on top
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),  # Convert 4D output to 2D
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),  # Regularization
    layers.Dense(5, activation='softmax')  # 5 classes for flowers
])

print("\nModified Model Summary:")
model.summary()
# Out:
# Modified Model Summary:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,113,541 (91.99 MB)
#  Trainable params: 525,829 (2.01 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# 3. Choose Fine-Tuning Strategy

# %%
# Unfreeze some layers for fine-tuning
for layer in base_model.layers[-10:]:  # Unfreeze last 10 layers
    layer.trainable = True

# %% [markdown]
# 3.2.2 Model Training and Fine-Tuning

# %% [markdown]
# Data Preprocessing (Resize to 224x224)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Define paths
base_dir = '/content/Flower_Dataset1/flower_images/'  # Main dataset directory

# Option 1: Automatic validation split
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # 20% for validation
)

# Training set (80%)
train_ds = train_datagen.flow_from_directory(
    base_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    subset='training',
    seed=123
)

# Validation set (20%)
val_ds = train_datagen.flow_from_directory(
    base_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    subset='validation',
    seed=123
)

print(f"Training classes: {train_ds.class_indices}")
print(f"Validation classes: {val_ds.class_indices}")
# Out:
# Found 4000 images belonging to 5 classes.
# Found 1000 images belonging to 5 classes.
# Training classes: {'Lilly': 0, 'Lotus': 1, 'Orchid': 2, 'Sunflower': 3, 'Tulip': 4}
# Validation classes: {'Lilly': 0, 'Lotus': 1, 'Orchid': 2, 'Sunflower': 3, 'Tulip': 4}

# %% [markdown]
# 2. Compile & Train the Model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),  # Lower LR for fine-tuning
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train for feature extraction
history = model.fit(
    train_ds,
    epochs=10,
    validation_data=val_ds
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 100s 656ms/step - accuracy: 0.2854 - loss: 1.5804 - val_accuracy: 0.2010 - val_loss: 1.9049
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 648ms/step - accuracy: 0.4282 - loss: 1.3701 - val_accuracy: 0.2430 - val_loss: 1.7776
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 75s 603ms/step - accuracy: 0.4851 - loss: 1.2595 - val_accuracy: 0.3270 - val_loss: 1.9624
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 86s 635ms/step - accuracy: 0.5186 - loss: 1.1889 - val_accuracy: 0.5090 - val_loss: 1.1873
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 647ms/step - accuracy: 0.5523 - loss: 1.1390 - val_accuracy: 0.4050 - val_loss: 1.6059
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 76s 607ms/step - accuracy: 0.5410 - loss: 1.1402 - val_accuracy: 0.3790 - val_loss: 1.5404
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 75s 599ms/step - accuracy: 0.5630 - loss: 1.0921 - val_accuracy: 0.4270 - val_loss: 1.4464
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 78s 622ms/step - accuracy: 0.5900 - loss: 1.0377 - val_accuracy: 0.4980 - val_loss: 1.2837
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 78s 591ms/step - accuracy: 0.5727 - loss: 1.0615 - val_accuracy: 0.4180 - val_loss: 1.4744
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 77s 615ms/step - accuracy: 0.5977 - loss: 1.0416 - val_accuracy: 0.2940 - val_loss: 2.2061

# %% [markdown]
# 3. Fine-Tuning (Optional)

# %%
# Unfreeze some layers and recompile
base_model.trainable = True
for layer in base_model.layers[:-10]:  # Freeze all except last 10 layers
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),  # Very low LR
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fine-tune for 5 more epochs
fine_tune_history = model.fit(
    train_ds,
    epochs=5,
    initial_epoch=history.epoch[-1],  # Continue from last epoch
    validation_data=val_ds
)

# %% [markdown]
# 3.2.3 Model Evaluation and Prediction
#
# 1. Evaluate Performance

# %%
# Evaluate on validation set
loss, accuracy = model.evaluate(val_ds)
print(f"Validation Accuracy: {accuracy*100:.2f}%")

# Generate classification report
from sklearn.metrics import classification_report
import numpy as np


CLASS_NAMES = ['Lilly', 'Lotus', 'Orchid', 'Sunflower', 'Tulip']

y_true = val_ds.classes
y_pred = np.argmax(model.predict(val_ds), axis=1)

print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))  # Fixed variable name
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 486ms/step - accuracy: 0.2657 - loss: 2.2108
# Validation Accuracy: 28.90%
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 580ms/step
#               precision    recall  f1-score   support
#
#        Lilly       0.22      0.07      0.10       200
#        Lotus       0.14      0.02      0.03       200
#       Orchid       0.26      0.03      0.05       200
#    Sunflower       0.17      0.01      0.02       200
#        Tulip       0.20      0.87      0.32       200
#
#     accuracy                           0.20      1000
#    macro avg       0.20      0.20      0.10      1000
# weighted avg       0.20      0.20      0.10      1000

# %% [markdown]
# 2. Compare with Part A Models

# %%
print("=== Model Comparison ===")
print("- Baseline Model (Part A): 79% Accuracy")
print("- Deeper Model (Part A): 71% Accuracy")
print("- Transfer Learning Model: {:.2f}% Accuracy".format(accuracy*100))
# Out:
# === Model Comparison ===
# - Baseline Model (Part A): 79% Accuracy
# - Deeper Model (Part A): 71% Accuracy
# - Transfer Learning Model: 28.90% Accuracy
